# %%
import pandas as pd

df = pd.read_csv('tweets_data.csv') 

print(df.head())
# Out:
#        username                                            content    date  \
# 0  AlexYsalex17  When I talk to Israeli people about current si...   Nov 2
# 1  AlexYsalex17  and with the help of Weibo, they eventually re...  Oct 19
# 2  AlexYsalex17  In China, Israeli Embassy has paid a lot of ef...  Oct 19
# 3  AlexYsalex17  Our reporter \n@AlexYsalex17\n takes a shot of...  Sep 13
# 4  AlexYsalex17  Thank you very much for answering the question...  Sep 14
#
#   likes retweets replies
# 0    16        0       5
# 1    17        4       2
# 2    18        5       2
# 3    18        3       2
# 4    33        1       9

# %%
import langid

# Function to detect language
def detect_language(text):
    try:
        lang, _ = langid.classify(text)
        return lang
    except Exception as e:
        return None

# Apply language detection to each tweet
df['language'] = df['content'].apply(detect_language)

# Display the language column
print(df[['content', 'language']])
# Out:
#                                                  content language
# 0      When I talk to Israeli people about current si...       en
# 1      and with the help of Weibo, they eventually re...       en
# 2      In China, Israeli Embassy has paid a lot of ef...       en
# 3      Our reporter \n@AlexYsalex17\n takes a shot of...       en
# 4      Thank you very much for answering the question...       en
# ...                                                  ...      ...
# 11582  Falling on the 7th day of the 7th lunar month,...       en
# 11583  Today marks the #WorldElephantDay, a time to g...       en
# 11584  Swimming in Kunming Lake at the Summer Palace ...       en
# 11585  The aerial view of Hejingwan New Village in Zu...       en
# 11586  The “Meilimount” VS. the “#Paramount”.\n\nIn 1...       en
#
# [11587 rows x 2 columns]

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download NLTK resources
nltk.download('stopwords')
nltk.download('punkt')
# Filter out non-English tweets (adjust as needed)
df_en = df[df['language'] == 'en']

# Function to preprocess text
def preprocess_text(text):
    stop_words = set(stopwords.words('english'))  # Adjust for your language
    words = word_tokenize(text)
    words = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words]
    return words

# Apply text preprocessing to each tweet
df_en['processed_content'] = df_en['content'].apply(preprocess_text)

# Display the processed content
print(df_en[['content', 'processed_content']])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\18253\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\18253\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                                  content  \
# 0      When I talk to Israeli people about current si...
# 1      and with the help of Weibo, they eventually re...
# 2      In China, Israeli Embassy has paid a lot of ef...
# 3      Our reporter \n@AlexYsalex17\n takes a shot of...
# 4      Thank you very much for answering the question...
# ...                                                  ...
# 11582  Falling on the 7th day of the 7th lunar month,...
# 11583  Today marks the #WorldElephantDay, a time to g...
# 11584  Swimming in Kunming Lake at the Summer Palace ...
# 11585  The aerial view of Hejingwan New Village in Zu...
# 11586  The “Meilimount” VS. the “#Paramount”.\n\nIn 1...
#
#                                        processed_content
# 0      [talk, israeli, people, current, situation, ga...
# 1      [help, weibo, eventually, retrieve, password, ...
# 2      [china, israeli, embassy, paid, lot, efforts, ...
# 3      [reporter, takes, shot, nicolasmaduro, venezue...
# 4      [thank, much, answering, question, global, tim...
# ...                                                  ...
# 11582  [falling, day, lunar, month, qixi, festival, w...
# 11583  [today, marks, worldelephantday, time, give, l...
# 11584  [swimming, kunming, lake, summer, palace, beij...
# 11585  [aerial, view, hejingwan, new, village, zunyi,...
# 11586  [meilimount, paramount, meili, snow, mountains...
#
# [7870 rows x 2 columns]
# C:\Users\18253\AppData\Local\Temp\ipykernel_5288\3785750034.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_en['processed_content'] = df_en['content'].apply(preprocess_text)

# %%
# Example: Sentiment Analysis using TextBlob
from textblob import TextBlob

# Function to perform sentiment analysis
def get_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

# Apply sentiment analysis to each tweet
df_en['sentiment'] = df_en['content'].apply(get_sentiment)

# Display the sentiment column
print(df_en[['content', 'sentiment']])
# Out:
#                                                  content  sentiment
# 0      When I talk to Israeli people about current si...   0.180000
# 1      and with the help of Weibo, they eventually re...   0.250000
# 2      In China, Israeli Embassy has paid a lot of ef...   0.022222
# 3      Our reporter \n@AlexYsalex17\n takes a shot of...   0.000000
# 4      Thank you very much for answering the question...   0.320000
# ...                                                  ...        ...
# 11582  Falling on the 7th day of the 7th lunar month,...  -0.050000
# 11583  Today marks the #WorldElephantDay, a time to g...   0.750000
# 11584  Swimming in Kunming Lake at the Summer Palace ...   0.000000
# 11585  The aerial view of Hejingwan New Village in Zu...   0.045455
# 11586  The “Meilimount” VS. the “#Paramount”.\n\nIn 1...   0.450000
#
# [7870 rows x 2 columns]
# C:\Users\18253\AppData\Local\Temp\ipykernel_5288\2324938785.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_en['sentiment'] = df_en['content'].apply(get_sentiment)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

df['content'] = df['content'].astype(str)
vectorizer = CountVectorizer(max_features=5000, stop_words='english')
X = vectorizer.fit_transform(df['content'])

lda = LatentDirichletAllocation(n_components=2, random_state=42)
lda.fit(X)

topic_assignments = lda.transform(X).argmax(axis=1)

df['topic'] = topic_assignments

# %%
df
# Out:
#               username                                            content  \
# 0         AlexYsalex17  When I talk to Israeli people about current si...
# 1         AlexYsalex17  and with the help of Weibo, they eventually re...
# 2         AlexYsalex17  In China, Israeli Embassy has paid a lot of ef...
# 3         AlexYsalex17  Our reporter \n@AlexYsalex17\n takes a shot of...
# 4         AlexYsalex17  Thank you very much for answering the question...
# ...                ...                                                ...
# 11582  _cultureexpress  Falling on the 7th day of the 7th lunar month,...
# 11583  _cultureexpress  Today marks the #WorldElephantDay, a time to g...
# 11584  _cultureexpress  Swimming in Kunming Lake at the Summer Palace ...
# 11585  _cultureexpress  The aerial view of Hejingwan New Village in Zu...
# 11586  _cultureexpress  The “Meilimount” VS. the “#Paramount”.\n\nIn 1...
#
#                date likes retweets replies language  topic
# 0             Nov 2    16        0       5       en      0
# 1            Oct 19    17        4       2       en      0
# 2            Oct 19    18        5       2       en      0
# 3            Sep 13    18        3       2       en      0
# 4            Sep 14    33        1       9       en      0
# ...             ...   ...      ...     ...      ...    ...
# 11582  Aug 12, 2021     1        1       0       en      0
# 11583  Aug 11, 2021     0        0       0       en      0
# 11584  Aug 11, 2021     3        0       0       en      0
# 11585  Aug 10, 2021     0        0       0       en      0
# 11586  Aug 10, 2021     0        0       0       en      0
#
# [11587 rows x 8 columns]

# %%
df['topic'].unique
# Out:
# <bound method Series.unique of 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 11582    0
# 11583    0
# 11584    0
# 11585    0
# 11586    0
# Name: topic, Length: 11587, dtype: int64>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, accuracy_score
# 0 is real 1 is bot
# Assuming 'content' is the tweet text and 'topic' is the labeled topic in your DataFrame 'df'

# Step 1: Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(df['content'], df['topic'], test_size=0.2, random_state=42)

# Step 2: TF-IDF Vectorization
vectorizer = TfidfVectorizer(max_features=5000, stop_words='english')
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# Step 3: Train a Text Classification Model
model = MultinomialNB()
model.fit(X_train_tfidf, y_train)

# Step 4: Evaluate the Model
y_pred = model.predict(X_test_tfidf)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\18253\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# c:\Users\18253\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\18253\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'topic'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5288\1090840688.py in <module>
#       8
#       9 # Step 1: Train-Test Split
# ---> 10 X_train, X_test, y_train, y_test = train_test_split(df['content'], df['topic'], test_size=0.2, random_state=42)
#      11
#      12 # Step 2: TF-IDF Vectorization
#
# c:\Users\18253\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# c:\Users\18253\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'topic'

# %%
import joblib

# Assuming 'model' is the trained classification model
# Assuming 'vectorizer' is the TF-IDF vectorizer used for text representation

# Save the model and vectorizer to files
joblib.dump(model, 'text_classification_model.joblib')
joblib.dump(vectorizer, 'tfidf_vectorizer.joblib')
# Out:
# ['tfidf_vectorizer.joblib']

# %%
# Load the model and vectorizer from files
loaded_model = joblib.load('text_classification_model.joblib')
loaded_vectorizer = joblib.load('tfidf_vectorizer.joblib')

# Example usage:
new_text = ["Is this a prediction about #BRICS?	", "The two presidents acknowledged the efforts of their respective teams",
            "I'm so happy to share that I trained this model after much efforts", "China is a great country","china beach san francisco"]
new_text_tfidf = loaded_vectorizer.transform(new_text)
predictions = loaded_model.predict(new_text_tfidf)

print("Predictions for new text:")
print(predictions)
# Out:
# Predictions for new text:
# [0 1 0 0 1]

# %%
from sklearn.svm import SVC

# Step 3: Train a Text Classification Model
svm_model = SVC(kernel='linear')  # You can choose different kernels like 'linear', 'rbf', etc.
svm_model.fit(X_train_tfidf, y_train)

# Step 4: Evaluate the SVM Model
y_svm_pred = svm_model.predict(X_test_tfidf)

print("SVM Accuracy:", accuracy_score(y_test, y_svm_pred))
print("SVM Classification Report:")
print(classification_report(y_test, y_svm_pred))
# Out:
# SVM Accuracy: 0.9672131147540983
# SVM Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1712
#            1       0.96      0.92      0.94       606
#
#     accuracy                           0.97      2318
#    macro avg       0.96      0.95      0.96      2318
# weighted avg       0.97      0.97      0.97      2318

# %%
joblib.dump(model, 'text_classification_model2.joblib')
joblib.dump(vectorizer, 'tfidf_vectorizer2.joblib')
# Out:
# ['tfidf_vectorizer2.joblib']

# %%
import joblib
# Load the model and vectorizer from files
loaded_model = joblib.load('text_classification_model2.joblib')
loaded_vectorizer = joblib.load('tfidf_vectorizer2.joblib')

# Example usage:
new_text = ["Is this a prediction about #BRICS?	", "The two presidents acknowledged the efforts of their respective teams",
            "I'm so happy to share that I trained this awsome model after so much efforts", "China is a great country","china beach san francisco"]
new_text_tfidf = loaded_vectorizer.transform(new_text)
predictions = loaded_model.predict(new_text_tfidf)

print("Predictions for new text:")
print(predictions)
# Out:
# Predictions for new text:
# [1 0 1 0 0]

# %%
df.to_csv("canis_data_with_topics.csv")

# %%
import re

def extract_hashtags(text):
    hashtags = re.findall(r'#(\w+)', text)
    return hashtags

# Assuming 'df' is your DataFrame with a 'content' column containing tweet text
df['hashtags'] = df['content'].apply(extract_hashtags)

# %%
df
# Out:
#              username                                            content  \
# date
# NaT      AlexYsalex17  When I talk to Israeli people about current si...
# NaT      AlexYsalex17  and with the help of Weibo, they eventually re...
# NaT      AlexYsalex17  In China, Israeli Embassy has paid a lot of ef...
# NaT      AlexYsalex17  Our reporter \n@AlexYsalex17\n takes a shot of...
# NaT      AlexYsalex17  Thank you very much for answering the question...
# ...               ...                                                ...
# NaT   _cultureexpress  Falling on the 7th day of the 7th lunar month,...
# NaT   _cultureexpress  Today marks the #WorldElephantDay, a time to g...
# NaT   _cultureexpress  Swimming in Kunming Lake at the Summer Palace ...
# NaT   _cultureexpress  The aerial view of Hejingwan New Village in Zu...
# NaT   _cultureexpress  The “Meilimount” VS. the “#Paramount”.\n\nIn 1...
#
#      likes retweets replies language  topic  \
# date
# NaT     16        0       5       en      0
# NaT     17        4       2       en      0
# NaT     18        5       2       en      0
# NaT     18        3       2       en      0
# NaT     33        1       9       en      0
# ...    ...      ...     ...      ...    ...
# NaT      1        1       0       en      0
# NaT      0        0       0       en      0
# NaT      3        0       0       en      0
# NaT      0        0       0       en      0
# NaT      0        0       0       en      0
#
#                                                hashtags
# date
# NaT                                       [Gaza, Hamas]
# NaT                           [IsraelAttack, Palestine]
# NaT                                                  []
# NaT                                 [Venezuela, Huawei]
# NaT                                                  []
# ...                                                 ...
# NaT   [Qixi, China, ValentinesDay, street, Hanghzou,...
# NaT   [WorldElephantDay, mammals, Earth, protection,...
# NaT                                                  []
# NaT                                    [BeautifulChina]
# NaT                                         [Paramount]
#
# [11587 rows x 8 columns]

# %%
from collections import Counter

# Flatten the list of hashtags and count occurrences
all_hashtags = [hashtag for hashtags in df['hashtags'] for hashtag in hashtags]
hashtag_counts = Counter(all_hashtags)

# Convert to DataFrame for easier visualization
df_hashtag_counts = pd.DataFrame(list(hashtag_counts.items()), columns=['Hashtag', 'Count'])
df_hashtag_counts = df_hashtag_counts.sort_values(by='Count', ascending=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you want to visualize the top 10 hashtags
top_n = 10

plt.figure(figsize=(10, 6))
sns.barplot(x='Count', y='Hashtag', data=df_hashtag_counts.head(top_n))
plt.title(f'Top {top_n} Hashtags')
plt.show()

# %%
df.columns
# Out:
# Index(['username', 'content', 'likes', 'retweets', 'replies', 'language',
#        'topic', 'hashtags'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame with 'topic' and 'hashtags' columns

# Step 1: Extract Hashtags
def extract_hashtags(text):
    hashtags = re.findall(r'#(\w+)', text)
    return hashtags

df['hashtags'] = df['content'].apply(extract_hashtags)

# Step 2: Count Hashtag Occurrences
df['count'] = df['hashtags'].apply(len)

# Step 3: Explode the DataFrame to separate rows for each hashtag
df_exploded = df.explode('hashtags')

# Step 4: Create a FacetGrid
g = sns.FacetGrid(df_exploded, col='topic', col_wrap=2, height=5, sharey=False)

# Step 5: Plot Bar Plots
g.map(sns.countplot, 'hashtags', palette='viridis', order=df_exploded['hashtags'].value_counts().index)

# Step 6: Adjust Layout
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Top Hashtags for Each Group (Real & Bot-generated)', fontsize=16)

plt.show()
# Out:
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 4102 (\N{MYANMAR LETTER CHA}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 4100 (\N{MYANMAR LETTER NGA}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20013 (\N{CJK UNIFIED IDEOGRAPH-4E2D}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 22269 (\N{CJK UNIFIED IDEOGRAPH-56FD}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 39118 (\N{CJK UNIFIED IDEOGRAPH-98CE}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 36825 (\N{CJK UNIFIED IDEOGRAPH-8FD9}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 23601 (\N{CJK UNIFIED IDEOGRAPH-5C31}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26159 (\N{CJK UNIFIED IDEOGRAPH-662F}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 27743 (\N{CJK UNIFIED IDEOGRAPH-6C5F}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 35199 (\N{CJK UNIFIED IDEOGRAPH-897F}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 27491 (\N{CJK UNIFIED IDEOGRAPH-6B63}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 35328 (\N{CJK UNIFIED IDEOGRAPH-8A00}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 28966 (\N{CJK UNIFIED IDEOGRAPH-7126}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 40670 (\N{CJK UNIFIED IDEOGRAPH-9EDE}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 22823 (\N{CJK UNIFIED IDEOGRAPH-5927}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 32654 (\N{CJK UNIFIED IDEOGRAPH-7F8E}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 31859 (\N{CJK UNIFIED IDEOGRAPH-7C73}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 39318 (\N{CJK UNIFIED IDEOGRAPH-9996}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 33075 (\N{CJK UNIFIED IDEOGRAPH-8133}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20250 (\N{CJK UNIFIED IDEOGRAPH-4F1A}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 35527 (\N{CJK UNIFIED IDEOGRAPH-8AC7}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 32858 (\N{CJK UNIFIED IDEOGRAPH-805A}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20841 (\N{CJK UNIFIED IDEOGRAPH-5169}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 23736 (\N{CJK UNIFIED IDEOGRAPH-5CB8}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20225 (\N{CJK UNIFIED IDEOGRAPH-4F01}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26989 (\N{CJK UNIFIED IDEOGRAPH-696D}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 23478 (\N{CJK UNIFIED IDEOGRAPH-5BB6}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 23791 (\N{CJK UNIFIED IDEOGRAPH-5CEF}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26371 (\N{CJK UNIFIED IDEOGRAPH-6703}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 33410 (\N{CJK UNIFIED IDEOGRAPH-8282}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 35270 (\N{CJK UNIFIED IDEOGRAPH-89C6}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 39057 (\N{CJK UNIFIED IDEOGRAPH-9891}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 27827 (\N{CJK UNIFIED IDEOGRAPH-6CB3}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21335 (\N{CJK UNIFIED IDEOGRAPH-5357}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 38617 (\N{CJK UNIFIED IDEOGRAPH-96D9}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21521 (\N{CJK UNIFIED IDEOGRAPH-5411}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 22868 (\N{CJK UNIFIED IDEOGRAPH-5954}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 36212 (\N{CJK UNIFIED IDEOGRAPH-8D74}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20849 (\N{CJK UNIFIED IDEOGRAPH-5171}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 31689 (\N{CJK UNIFIED IDEOGRAPH-7BC9}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 22818 (\N{CJK UNIFIED IDEOGRAPH-5922}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 27599 (\N{CJK UNIFIED IDEOGRAPH-6BCF}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 19968 (\N{CJK UNIFIED IDEOGRAPH-4E00}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21513 (\N{CJK UNIFIED IDEOGRAPH-5409}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20889 (\N{CJK UNIFIED IDEOGRAPH-5199}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 30495 (\N{CJK UNIFIED IDEOGRAPH-771F}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26412 (\N{CJK UNIFIED IDEOGRAPH-672C}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12497 (\N{KATAKANA LETTER PA}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12531 (\N{KATAKANA LETTER N}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12480 (\N{KATAKANA LETTER DA}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 38306 (\N{CJK UNIFIED IDEOGRAPH-95A2}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20418 (\N{CJK UNIFIED IDEOGRAPH-4FC2}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 37073 (\N{CJK UNIFIED IDEOGRAPH-90D1}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 24030 (\N{CJK UNIFIED IDEOGRAPH-5DDE}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 22863 (\N{CJK UNIFIED IDEOGRAPH-594F}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21709 (\N{CJK UNIFIED IDEOGRAPH-54CD}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 19997 (\N{CJK UNIFIED IDEOGRAPH-4E1D}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 36335 (\N{CJK UNIFIED IDEOGRAPH-8DEF}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21326 (\N{CJK UNIFIED IDEOGRAPH-534E}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 31456 (\N{CJK UNIFIED IDEOGRAPH-7AE0}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 33258 (\N{CJK UNIFIED IDEOGRAPH-81EA}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 28982 (\N{CJK UNIFIED IDEOGRAPH-7136}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26178 (\N{CJK UNIFIED IDEOGRAPH-6642}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 35413 (\N{CJK UNIFIED IDEOGRAPH-8A55}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 24179 (\N{CJK UNIFIED IDEOGRAPH-5E73}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21644 (\N{CJK UNIFIED IDEOGRAPH-548C}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12392 (\N{HIRAGANA LETTER TO}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20154 (\N{CJK UNIFIED IDEOGRAPH-4EBA}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 27177 (\N{CJK UNIFIED IDEOGRAPH-6A29}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12434 (\N{HIRAGANA LETTER WO}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20869 (\N{CJK UNIFIED IDEOGRAPH-5185}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 25919 (\N{CJK UNIFIED IDEOGRAPH-653F}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 24178 (\N{CJK UNIFIED IDEOGRAPH-5E72}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 28169 (\N{CJK UNIFIED IDEOGRAPH-6E09}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12398 (\N{HIRAGANA LETTER NO}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21475 (\N{CJK UNIFIED IDEOGRAPH-53E3}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 23455 (\N{CJK UNIFIED IDEOGRAPH-5B9F}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12395 (\N{HIRAGANA LETTER NI}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12377 (\N{HIRAGANA LETTER SU}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12427 (\N{HIRAGANA LETTER RU}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12394 (\N{HIRAGANA LETTER NA}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 34255 (\N{CJK UNIFIED IDEOGRAPH-85CF}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26519 (\N{CJK UNIFIED IDEOGRAPH-6797}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 33437 (\N{CJK UNIFIED IDEOGRAPH-829D}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12450 (\N{KATAKANA LETTER A}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12472 (\N{KATAKANA LETTER ZI}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 31478 (\N{CJK UNIFIED IDEOGRAPH-7AF6}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 25216 (\N{CJK UNIFIED IDEOGRAPH-6280}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12461 (\N{KATAKANA LETTER KI}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12527 (\N{KATAKANA LETTER WA}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12489 (\N{KATAKANA LETTER DO}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 27880 (\N{CJK UNIFIED IDEOGRAPH-6CE8}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26144 (\N{CJK UNIFIED IDEOGRAPH-6620}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 30011 (\N{CJK UNIFIED IDEOGRAPH-753B}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26032 (\N{CJK UNIFIED IDEOGRAPH-65B0}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20316 (\N{CJK UNIFIED IDEOGRAPH-4F5C}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 29066 (\N{CJK UNIFIED IDEOGRAPH-718A}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 35987 (\N{CJK UNIFIED IDEOGRAPH-8C93}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 35486 (\N{CJK UNIFIED IDEOGRAPH-8A9E}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 23398 (\N{CJK UNIFIED IDEOGRAPH-5B66}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 32722 (\N{CJK UNIFIED IDEOGRAPH-7FD2}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 2342 (\N{DEVANAGARI LETTER DA}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Matplotlib currently does not support Devanagari natively.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21320 (\N{CJK UNIFIED IDEOGRAPH-5348}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 22812 (\N{CJK UNIFIED IDEOGRAPH-591C}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 23567 (\N{CJK UNIFIED IDEOGRAPH-5C0F}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 35821 (\N{CJK UNIFIED IDEOGRAPH-8BED}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12463 (\N{KATAKANA LETTER KU}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26446 (\N{CJK UNIFIED IDEOGRAPH-674E}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 24375 (\N{CJK UNIFIED IDEOGRAPH-5F37}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 30000 (\N{CJK UNIFIED IDEOGRAPH-7530}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 25991 (\N{CJK UNIFIED IDEOGRAPH-6587}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 38596 (\N{CJK UNIFIED IDEOGRAPH-96C4}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21451 (\N{CJK UNIFIED IDEOGRAPH-53CB}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 22909 (\N{CJK UNIFIED IDEOGRAPH-597D}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26465 (\N{CJK UNIFIED IDEOGRAPH-6761}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 32004 (\N{CJK UNIFIED IDEOGRAPH-7D04}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 36817 (\N{CJK UNIFIED IDEOGRAPH-8FD1}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12491 (\N{KATAKANA LETTER NI}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12517 (\N{KATAKANA LETTER SMALL YU}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12473 (\N{KATAKANA LETTER SU}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 33337 (\N{CJK UNIFIED IDEOGRAPH-8239}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 25215 (\N{CJK UNIFIED IDEOGRAPH-627F}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20011 (\N{CJK UNIFIED IDEOGRAPH-4E2B}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 25105 (\N{CJK UNIFIED IDEOGRAPH-6211}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20826 (\N{CJK UNIFIED IDEOGRAPH-515A}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20195 (\N{CJK UNIFIED IDEOGRAPH-4EE3}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 34920 (\N{CJK UNIFIED IDEOGRAPH-8868}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 29615 (\N{CJK UNIFIED IDEOGRAPH-73AF}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 25253 (\N{CJK UNIFIED IDEOGRAPH-62A5}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 23380 (\N{CJK UNIFIED IDEOGRAPH-5B54}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 23376 (\N{CJK UNIFIED IDEOGRAPH-5B50}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 31435 (\N{CJK UNIFIED IDEOGRAPH-7ACB}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20908 (\N{CJK UNIFIED IDEOGRAPH-51AC}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 78069 (\N{EGYPTIAN HIEROGLYPH E030}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 19996 (\N{CJK UNIFIED IDEOGRAPH-4E1C}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21271 (\N{CJK UNIFIED IDEOGRAPH-5317}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 24191 (\N{CJK UNIFIED IDEOGRAPH-5E7F}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 37325 (\N{CJK UNIFIED IDEOGRAPH-91CD}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 38451 (\N{CJK UNIFIED IDEOGRAPH-9633}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 38738 (\N{CJK UNIFIED IDEOGRAPH-9752}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 32701 (\N{CJK UNIFIED IDEOGRAPH-7FBD}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 29983 (\N{CJK UNIFIED IDEOGRAPH-751F}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 32080 (\N{CJK UNIFIED IDEOGRAPH-7D50}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 24358 (\N{CJK UNIFIED IDEOGRAPH-5F26}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 38626 (\N{CJK UNIFIED IDEOGRAPH-96E2}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 23130 (\N{CJK UNIFIED IDEOGRAPH-5A5A}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 32418 (\N{CJK UNIFIED IDEOGRAPH-7EA2}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26071 (\N{CJK UNIFIED IDEOGRAPH-65D7}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21152 (\N{CJK UNIFIED IDEOGRAPH-52A0}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 27833 (\N{CJK UNIFIED IDEOGRAPH-6CB9}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 33392 (\N{CJK UNIFIED IDEOGRAPH-8270}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 3592 (\N{THAI CHARACTER CHO CHAN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12364 (\N{HIRAGANA LETTER GA}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12391 (\N{HIRAGANA LETTER DE}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 31169 (\N{CJK UNIFIED IDEOGRAPH-79C1}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 19990 (\N{CJK UNIFIED IDEOGRAPH-4E16}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 30028 (\N{CJK UNIFIED IDEOGRAPH-754C}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 36947 (\N{CJK UNIFIED IDEOGRAPH-9053}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 19981 (\N{CJK UNIFIED IDEOGRAPH-4E0D}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 23396 (\N{CJK UNIFIED IDEOGRAPH-5B64}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 22825 (\N{CJK UNIFIED IDEOGRAPH-5929}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 19979 (\N{CJK UNIFIED IDEOGRAPH-4E0B}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 32769 (\N{CJK UNIFIED IDEOGRAPH-8001}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 29240 (\N{CJK UNIFIED IDEOGRAPH-7238}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 33590 (\N{CJK UNIFIED IDEOGRAPH-8336}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 39321 (\N{CJK UNIFIED IDEOGRAPH-9999}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26684 (\N{CJK UNIFIED IDEOGRAPH-683C}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 37324 (\N{CJK UNIFIED IDEOGRAPH-91CC}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 25289 (\N{CJK UNIFIED IDEOGRAPH-62C9}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26118 (\N{CJK UNIFIED IDEOGRAPH-6606}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26126 (\N{CJK UNIFIED IDEOGRAPH-660E}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26007 (\N{CJK UNIFIED IDEOGRAPH-6597}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 33457 (\N{CJK UNIFIED IDEOGRAPH-82B1}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21321 (\N{CJK UNIFIED IDEOGRAPH-5349}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 24066 (\N{CJK UNIFIED IDEOGRAPH-5E02}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 22330 (\N{CJK UNIFIED IDEOGRAPH-573A}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26377 (\N{CJK UNIFIED IDEOGRAPH-6709}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 31181 (\N{CJK UNIFIED IDEOGRAPH-79CD}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21483 (\N{CJK UNIFIED IDEOGRAPH-53EB}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20113 (\N{CJK UNIFIED IDEOGRAPH-4E91}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 27963 (\N{CJK UNIFIED IDEOGRAPH-6D3B}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 22836 (\N{CJK UNIFIED IDEOGRAPH-5934}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20687 (\N{CJK UNIFIED IDEOGRAPH-50CF}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 31179 (\N{CJK UNIFIED IDEOGRAPH-79CB}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 31786 (\N{CJK UNIFIED IDEOGRAPH-7C2A}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 22260 (\N{CJK UNIFIED IDEOGRAPH-56F4}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20845 (\N{CJK UNIFIED IDEOGRAPH-516D}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 39034 (\N{CJK UNIFIED IDEOGRAPH-987A}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21330 (\N{CJK UNIFIED IDEOGRAPH-5352}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20083 (\N{CJK UNIFIED IDEOGRAPH-4E73}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 22411 (\N{CJK UNIFIED IDEOGRAPH-578B}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12467 (\N{KATAKANA LETTER KO}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12525 (\N{KATAKANA LETTER RO}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12490 (\N{KATAKANA LETTER NA}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 12481 (\N{KATAKANA LETTER TI}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 33945 (\N{CJK UNIFIED IDEOGRAPH-8499}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21476 (\N{CJK UNIFIED IDEOGRAPH-53E4}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 28040 (\N{CJK UNIFIED IDEOGRAPH-6D88}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 38450 (\N{CJK UNIFIED IDEOGRAPH-9632}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21592 (\N{CJK UNIFIED IDEOGRAPH-5458}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 38750 (\N{CJK UNIFIED IDEOGRAPH-975E}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 36951 (\N{CJK UNIFIED IDEOGRAPH-9057}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 38065 (\N{CJK UNIFIED IDEOGRAPH-94B1}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 22616 (\N{CJK UNIFIED IDEOGRAPH-5858}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26087 (\N{CJK UNIFIED IDEOGRAPH-65E7}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 37329 (\N{CJK UNIFIED IDEOGRAPH-91D1}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 23665 (\N{CJK UNIFIED IDEOGRAPH-5C71}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20122 (\N{CJK UNIFIED IDEOGRAPH-4E9A}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 22826 (\N{CJK UNIFIED IDEOGRAPH-592A}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 32463 (\N{CJK UNIFIED IDEOGRAPH-7ECF}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21512 (\N{CJK UNIFIED IDEOGRAPH-5408}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26494 (\N{CJK UNIFIED IDEOGRAPH-677E}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 30086 (\N{CJK UNIFIED IDEOGRAPH-7586}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 28895 (\N{CJK UNIFIED IDEOGRAPH-70DF}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 29483 (\N{CJK UNIFIED IDEOGRAPH-732B}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 27969 (\N{CJK UNIFIED IDEOGRAPH-6D41}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 28010 (\N{CJK UNIFIED IDEOGRAPH-6D6A}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 33487 (\N{CJK UNIFIED IDEOGRAPH-82CF}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26497 (\N{CJK UNIFIED IDEOGRAPH-6781}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20140 (\N{CJK UNIFIED IDEOGRAPH-4EAC}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 27983 (\N{CJK UNIFIED IDEOGRAPH-6D4F}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 28165 (\N{CJK UNIFIED IDEOGRAPH-6E05}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 19978 (\N{CJK UNIFIED IDEOGRAPH-4E0A}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 25112 (\N{CJK UNIFIED IDEOGRAPH-6218}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 27494 (\N{CJK UNIFIED IDEOGRAPH-6B66}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 27721 (\N{CJK UNIFIED IDEOGRAPH-6C49}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 31070 (\N{CJK UNIFIED IDEOGRAPH-795E}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 33311 (\N{CJK UNIFIED IDEOGRAPH-821F}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21313 (\N{CJK UNIFIED IDEOGRAPH-5341}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 19971 (\N{CJK UNIFIED IDEOGRAPH-4E03}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21495 (\N{CJK UNIFIED IDEOGRAPH-53F7}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 35251 (\N{CJK UNIFIED IDEOGRAPH-89B3}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 23519 (\N{CJK UNIFIED IDEOGRAPH-5BDF}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\18253\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 30524 (\N{CJK UNIFIED IDEOGRAPH-773C}) missing from current font.
# ...
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 35841 (\N{CJK UNIFIED IDEOGRAPH-8C01}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 22840 (\N{CJK UNIFIED IDEOGRAPH-5938}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 21681 (\N{CJK UNIFIED IDEOGRAPH-54B1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 20065 (\N{CJK UNIFIED IDEOGRAPH-4E61}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 20219 (\N{CJK UNIFIED IDEOGRAPH-4EFB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 38271 (\N{CJK UNIFIED IDEOGRAPH-957F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 26480 (\N{CJK UNIFIED IDEOGRAPH-6770}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 24320 (\N{CJK UNIFIED IDEOGRAPH-5F00}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 24212 (\N{CJK UNIFIED IDEOGRAPH-5E94}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 26399 (\N{CJK UNIFIED IDEOGRAPH-671F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 36127 (\N{CJK UNIFIED IDEOGRAPH-8D1F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 38754 (\N{CJK UNIFIED IDEOGRAPH-9762}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 33286 (\N{CJK UNIFIED IDEOGRAPH-8206}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 24773 (\N{CJK UNIFIED IDEOGRAPH-60C5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 20204 (\N{CJK UNIFIED IDEOGRAPH-4EEC}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 38752 (\N{CJK UNIFIED IDEOGRAPH-9760}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 20159 (\N{CJK UNIFIED IDEOGRAPH-4EBF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 30123 (\N{CJK UNIFIED IDEOGRAPH-75AB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 27835 (\N{CJK UNIFIED IDEOGRAPH-6CBB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 20173 (\N{CJK UNIFIED IDEOGRAPH-4ECD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 23041 (\N{CJK UNIFIED IDEOGRAPH-5A01}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 32961 (\N{CJK UNIFIED IDEOGRAPH-80C1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 12484 (\N{KATAKANA LETTER TU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 31532 (\N{CJK UNIFIED IDEOGRAPH-7B2C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 38499 (\N{CJK UNIFIED IDEOGRAPH-9663}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 24373 (\N{CJK UNIFIED IDEOGRAPH-5F35}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 24950 (\N{CJK UNIFIED IDEOGRAPH-6176}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 31680 (\N{CJK UNIFIED IDEOGRAPH-7BC0}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 21331 (\N{CJK UNIFIED IDEOGRAPH-5353}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 12465 (\N{KATAKANA LETTER KE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 12508 (\N{KATAKANA LETTER BO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 12523 (\N{KATAKANA LETTER RU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 22899 (\N{CJK UNIFIED IDEOGRAPH-5973}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 26726 (\N{CJK UNIFIED IDEOGRAPH-6866}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 30008 (\N{CJK UNIFIED IDEOGRAPH-7538}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 20892 (\N{CJK UNIFIED IDEOGRAPH-519C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 38215 (\N{CJK UNIFIED IDEOGRAPH-9547}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 36169 (\N{CJK UNIFIED IDEOGRAPH-8D49}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 21439 (\N{CJK UNIFIED IDEOGRAPH-53BF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 31119 (\N{CJK UNIFIED IDEOGRAPH-798F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 24247 (\N{CJK UNIFIED IDEOGRAPH-5EB7}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 22827 (\N{CJK UNIFIED IDEOGRAPH-592B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 36211 (\N{CJK UNIFIED IDEOGRAPH-8D73}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 21407 (\N{CJK UNIFIED IDEOGRAPH-539F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 35488 (\N{CJK UNIFIED IDEOGRAPH-8AA0}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 37428 (\N{CJK UNIFIED IDEOGRAPH-9234}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 25144 (\N{CJK UNIFIED IDEOGRAPH-6238}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 32224 (\N{CJK UNIFIED IDEOGRAPH-7DE0}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 12414 (\N{HIRAGANA LETTER MA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 12426 (\N{HIRAGANA LETTER RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 23431 (\N{CJK UNIFIED IDEOGRAPH-5B87}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 23449 (\N{CJK UNIFIED IDEOGRAPH-5B99}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 12519 (\N{KATAKANA LETTER SMALL YO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 36650 (\N{CJK UNIFIED IDEOGRAPH-8F2A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 22258 (\N{CJK UNIFIED IDEOGRAPH-56F2}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 12362 (\N{HIRAGANA LETTER O}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 36020 (\N{CJK UNIFIED IDEOGRAPH-8CB4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 12363 (\N{HIRAGANA LETTER KA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 12367 (\N{HIRAGANA LETTER KU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 12428 (\N{HIRAGANA LETTER RE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 12412 (\N{HIRAGANA LETTER BO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 34907 (\N{CJK UNIFIED IDEOGRAPH-885B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 28204 (\N{CJK UNIFIED IDEOGRAPH-6E2C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 20301 (\N{CJK UNIFIED IDEOGRAPH-4F4D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 12512 (\N{KATAKANA LETTER MU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 33976 (\N{CJK UNIFIED IDEOGRAPH-84B8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 25925 (\N{CJK UNIFIED IDEOGRAPH-6545}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 20912 (\N{CJK UNIFIED IDEOGRAPH-51B0}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 23707 (\N{CJK UNIFIED IDEOGRAPH-5C9B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 22806 (\N{CJK UNIFIED IDEOGRAPH-5916}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 32178 (\N{CJK UNIFIED IDEOGRAPH-7DB2}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 20126 (\N{CJK UNIFIED IDEOGRAPH-4E9E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 32147 (\N{CJK UNIFIED IDEOGRAPH-7D93}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 32068 (\N{CJK UNIFIED IDEOGRAPH-7D44}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 32340 (\N{CJK UNIFIED IDEOGRAPH-7E54}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 21487 (\N{CJK UNIFIED IDEOGRAPH-53EF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\18253\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 23401 (\N{CJK UNIFIED IDEOGRAPH-5B69}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\18253\anaconda3\lib\site-packages (1.9.2)
# Requirement already satisfied: pillow in c:\users\18253\anaconda3\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\18253\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\18253\anaconda3\lib\site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\18253\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\18253\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\18253\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\18253\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\18253\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\18253\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\18253\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud

# Assuming df is your DataFrame with 'topic' and 'content' columns

# Step 1: Extract Hashtags
def extract_hashtags(text):
    hashtags = re.findall(r'#(\w+)', text)
    return hashtags

df['hashtags'] = df['content'].apply(extract_hashtags)

# Step 2: Combine hashtags for each topic into a single list
df_grouped = df.groupby('topic')['hashtags'].apply(lambda x: [item for sublist in x for item in sublist]).reset_index()

# Step 3: Generate and display a word cloud for each topic
for index, row in df_grouped.iterrows():
    topic = row['topic']
    hashtags_text = ' '.join(row['hashtags'])  # Combine the list of hashtags into a single string

    # Generate word cloud
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(hashtags_text)
    group_name = ['Real', "Bot-generated"]
    # Display word cloud
    plt.figure(figsize=(10, 6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(f'Word Cloud for Hashtags - {group_name[topic]}')
    plt.show()

# %%
from wordcloud import WordCloud
import re

# Assuming df is your DataFrame with 'topic' and 'content' columns

# Step 1: Extract Hashtags
def extract_hashtags(text):
    hashtags = re.findall(r'#(\w+)', text)
    return hashtags

df['hashtags'] = df['content'].apply(extract_hashtags)

# Step 2: Combine hashtags for each topic into a single list
df_grouped = df.groupby('topic')['hashtags'].apply(lambda x: [re.sub(r'\W', '', item) for sublist in x for item in sublist]).reset_index()

# Step 3: Generate and display a word cloud for each topic
for index, row in df_grouped.iterrows():
    topic = row['topic']
    hashtags_text = ' '.join(row['hashtags'])  # Combine the list of hashtags into a single string

    # Generate word cloud
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(hashtags_text)
    group_name = ['Real', "Bot-generated"]
    # Display word cloud
    plt.figure(figsize=(10, 6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(f'Word Cloud for Hashtags - {group_name[topic]}')
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame with 'topic' and 'hashtags' columns

# Step 1: Extract Hashtags
def extract_hashtags(text):
    hashtags = re.findall(r'#(\w+)', text)
    return hashtags

df['hashtags'] = df['content'].apply(extract_hashtags)

# Step 2: Count Hashtag Occurrences
df['count'] = df['hashtags'].apply(len)

# Step 3: Explode the DataFrame to separate rows for each hashtag
df_exploded = df.explode('hashtags')

# Step 4: Get the top 10 hashtags for each topic
top_hashtags_by_topic = df_exploded.groupby(['topic', 'hashtags']).size().reset_index(name='count')
top_hashtags_by_topic = top_hashtags_by_topic.sort_values(['topic', 'count'], ascending=[True, False])
top_hashtags_by_topic = top_hashtags_by_topic.groupby('topic').head(10)

# Step 5: Create a FacetGrid
g = sns.FacetGrid(df_exploded, col='topic', col_wrap=2, height=5, sharey=False)

# Step 6: Plot Bar Plots for the top 10 hashtags
g.map(sns.barplot, 'count', 'hashtags', palette='viridis', ci=None, order=top_hashtags_by_topic['hashtags'])

# Step 7: Adjust Layout
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Top 10 Hashtags for Each Group Real (0) & Bot-generated(1)', fontsize=16)

plt.show()

# %%
df.to_excel('Data with Hashtag.xlsx')

# %%
import pandas as pd
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt

# Assuming df is your DataFrame with 'entity owner' and 'parent entity' columns
df = canis
# Step 1: Create a DataFrame with unique entities
unique_entities = pd.concat([df['Entity owner (English)'], df['Parent entity (English)']]).unique()
df_entities = pd.DataFrame(unique_entities, columns=['Entity owner (English)'])

# Step 2: Create a distance matrix based on the relationships between entities
matrix = pd.DataFrame(index=df_entities['Entity owner (English)'], columns=df_entities['Entity owner (English)'], data=0)

for _, row in df.iterrows():
    matrix.at[row['Entity owner (English)'], row['Parent entity (English)']] = 1

# Step 3: Perform hierarchical clustering
linkage_matrix = linkage(matrix, method='ward')

# Step 4: Plot the dendrogram
plt.figure(figsize=(20, 10))
dendrogram(linkage_matrix, labels=matrix.index, orientation='top', leaf_rotation=90)
plt.title('Dendrogram of Entity Relationships')
plt.xlabel('Entities')
plt.ylabel('Distance')
plt.show()

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt

# Assuming df is your DataFrame with 'entity owner' and 'parent entity' columns

# Step 1: Create a DataFrame with unique entities
unique_entities = pd.concat([df['Entity owner (English)'], df['Parent entity (English)']]).unique()
df_entities = pd.DataFrame(unique_entities, columns=['Entity owner (English)'])

# Step 2: Create a distance matrix based on the relationships between entities
matrix = pd.DataFrame(index=df_entities['Entity owner (English)'], columns=df_entities['Entity owner (English)'], data=0)

for _, row in df.iterrows():
    matrix.at[row['Entity owner (English)'], row['Parent entity (English)']] = 1

# Step 3: Perform hierarchical clustering
linkage_matrix = linkage(matrix, method='ward')

# Step 4: Plot the dendrogram, excluding the last 20 entities
plt.figure(figsize=(20, 10))
dendrogram(linkage_matrix, labels=matrix.index, orientation='top', leaf_rotation=90, truncate_mode='lastp', p=matrix.shape[0]-50)
plt.title('Dendrogram of Entity Relationships')
plt.xlabel('Entities')
plt.ylabel('Distance')
plt.savefig('your_plot_filename.png')

plt.show()

# %%
plt.savefig('dendrogram.png')

# %%
canis = pd.read_csv('canis_region_corrected.csv')

# %%
import pandas as pd

# Assuming df is your DataFrame and 'column_name' is the column for which you want to find unique values
unique_values = canis['Language'].unique()

# Print or use the unique values as needed
print(len(unique_values))

unique_values2 = canis['Region of Focus'].unique()

# Print or use the unique values as needed
print(len(unique_values2)) 

unique_values3 = canis['Parent entity (English)'].unique()

# Print or use the unique values as needed
print(len(unique_values3))
# Out:
# 46
# 171
# 69

# %%
import numpy as np

# Assuming df is your DataFrame with 'entity' and 'parent entity' columns
df = canis
# Get unique values from both columns
unique_entities4 = np.unique(np.concatenate([df['Entity owner (English)'].unique(), df['Parent entity (English)'].unique()]))

# Print or use the unique values as needed
print(len(unique_entities4))
# Out:
# 152
